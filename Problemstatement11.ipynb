# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("heart.csv")
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# ### BARPLOT

# %%
sns.barplot(data=data,x="sex",y="age")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %% [markdown]
# ### COUNTPLOT

# %%
plt.figure(figsize = (10,4) ,dpi = 100)
color_palette = sns.color_palette("Accent_r")
sns.set_palette(color_palette)
sns.countplot(x = "slope", data=data)
# Out:
# <AxesSubplot:xlabel='slope', ylabel='count'>

# %%
plt.figure(figsize = (10,4), dpi =100)
color_palette = sns.color_palette("Accent_r")
sns.set_palette(color_palette)
sns.countplot(x = "age" , data=data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
plt.figure(figsize = (10,4) , dpi = 100)
color_palette = sns.color_palette("Accent_r")
sns.set_palette(color_palette)
sns.countplot(x = "sex" , data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# ### PIECHART

# %%
plt.figure(figsize = (10, 4), dpi = 100)
grp = dict(data.groupby('thal').groups)
m = {}
for key, val in grp.items():
    if key in m:
        m[key] += len(val)
    else:
        m[key] = len(val)
plt.title("Distribution of thal")
plt.pie(m.values(), labels = m.keys())
plt.show()

# %%
plt.figure(figsize = (10,4) , dpi=100)
grp = dict(data.groupby('sex').groups)
m = {}
for key, val in grp.items():
    if key in m:
        m[key] = len(val)
    else:
        m[key] = len(val)
plt.title("Distribution of Gender")
plt.pie(m.values(), labels = m.keys())
plt.show()

# %% [markdown]
# ### BARPLOT

# %%
plt.figure(figsize = (10,4) , dpi =100)
color_palette = sns.color_palette("magma")
sns.set_palette(color_palette)
sns.barplot(x = "slope" , y="chol",data=data)
plt.show()

# %%
plt.figure(figsize = (10,4), dpi = 100)
color_palette = sns.color_palette("magma")
sns.set_palette(color_palette)
sns.barplot(x="sex" , y="thal",data=data)
plt.show()

# %%
plt.figure(figsize = (10,4) , dpi = 100)
color_palette = sns.color_palette("magma")
sns.set_palette(color_palette)
sns.barplot(x="age",y="chol",data=data)
plt.show()

# %% [markdown]
# ### LINE PLOT

# %%
plt.figure(figsize = (10,4),dpi = 100)
color_palette = sns.color_palette("magma")
sns.set_palette(color_palette)
sns.lineplot(x = "age",y="chol",data=data)
plt.show()

# %%
plt.figure(figsize = (10,4) , dpi = 100)
color_palette = sns.color_palette("magma")
sns.set_palette(color_palette)
sns.lineplot(x="age",y="trestbps",data=data)
plt.show()

# %% [markdown]
# ### BOXPLOT

# %%
plt.figure(figsize = (10,4) , dpi = 100)
sns.boxplot(x = "chol", data=data)
# Out:
# <AxesSubplot:xlabel='chol'>

# %%
plt.figure(figsize = (10,4), dpi = 100)
sns.boxplot(x = "trestbps",data=data)
# Out:
# <AxesSubplot:xlabel='trestbps'>

# %% [markdown]
# ### HEATMAP

# %%
plt.figure(figsize = (10,4) , dpi = 100)
color_palette = sns.color_palette("magma")
sns.heatmap(data.corr(), vmax=0.9, annot=True,cmap = color_palette)
# Out:
# <AxesSubplot:>
