# %%
import pandas as pd
import numpy as np

# %%
data1 = pd.read_csv("airquality1.csv")
# Out:
# C:\Users\Lenovo\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data1
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
data2 = pd.read_csv("heart.csv")
data2
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data1.shape
# Out:
# (435742, 13)

# %%
data2.shape
# Out:
# (1025, 14)

# %%
data1.isnull().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
data1['stn_code']=data1['stn_code'].fillna(0)
data1
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739        0                 NaN  andaman-and-nicobar-islands        NaN
# 435740        0                 NaN                  Lakshadweep        NaN
# 435741        0                 NaN                      Tripura        NaN
#
#                                            agency  \
# ...

# %%
data2.fillna(0)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data1.isnull().sum()
# Out:
# stn_code                            0
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                             5393
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
data = data1.drop('agency',axis=1)
data
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739        0                 NaN  andaman-and-nicobar-islands        NaN
# 435740        0                 NaN                  Lakshadweep        NaN
# 435741        0                 NaN                      Tripura        NaN
#
# ...

# %%
data.type.unique()
# Out:
# array(['Residential, Rural and other Areas', 'Industrial Area', nan,
#        'Sensitive Area', 'Industrial Areas', 'Residential and others',
#        'Sensitive Areas', 'Industrial', 'Residential', 'RIRUO',
#        'Sensitive'], dtype=object)

# %%
data['type'] = data['type'].replace(['Industrial Areas','Residential and others','Sensitive Areas','Industrial','Residential','Sensitive'],['Industrial Area','Residential and other Areas','Sensitive Area','Industrial Area','Residential Area','Sensitive Area'])

# %%
data.type.unique()
# Out:
# array(['Residential, Rural and other Areas', 'Industrial Area', nan,
#        'Sensitive Area', 'Residential and other Areas',
#        'Residential Area', 'RIRUO'], dtype=object)

# %%
data['so2'].fillna(int(data['so2'].mean()), inplace=True)

# %%
data['no2'].fillna(int(data['no2'].mean()), inplace=True)

# %%
data['rspm'].fillna(int(data['rspm'].mean()), inplace=True)

# %%
data['spm'].fillna(int(data['spm'].mean()), inplace=True)

# %%
data['pm2_5'].fillna(int(data['pm2_5'].mean()), inplace=True)

# %%
data.isnull().sum()
# Out:
# stn_code                           0
# sampling_date                      3
# state                              0
# location                           3
# type                            5393
# so2                                0
# no2                                0
# rspm                               0
# spm                                0
# location_monitoring_station    27491
# pm2_5                              0
# date                               7
# dtype: int64

# %%
data['date'] = pd.to_datetime(data['date'],format='%m/%d/%Y')
data['date'] = pd.DatetimeIndex(data['date']).year

# %%
data3=data.rename(columns={"date":"year"})
data3
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739        0                 NaN  andaman-and-nicobar-islands        NaN
# 435740        0                 NaN                  Lakshadweep        NaN
# 435741        0                 NaN                      Tripura        NaN
#
# ...

# %%
data4 = data3.drop('stn_code',axis=1)
data4
# Out:
#              sampling_date                        state   location  \
# 0       February - M021990               Andhra Pradesh  Hyderabad
# 1       February - M021990               Andhra Pradesh  Hyderabad
# 2       February - M021990               Andhra Pradesh  Hyderabad
# 3          March - M031990               Andhra Pradesh  Hyderabad
# 4          March - M031990               Andhra Pradesh  Hyderabad
# ...                    ...                          ...        ...
# 435737            24-12-15                  West Bengal   ULUBERIA
# 435738            29-12-15                  West Bengal   ULUBERIA
# 435739                 NaN  andaman-and-nicobar-islands        NaN
# 435740                 NaN                  Lakshadweep        NaN
# 435741                 NaN                      Tripura        NaN
#
#                                       type   so2   no2   rspm    spm  \
# 0       Residential, Rural and other Areas   4.8  17.4  108.0  220.0
# ...

# %%
data4.isnull().sum()
# Out:
# sampling_date                      3
# state                              0
# location                           3
# type                            5393
# so2                                0
# no2                                0
# rspm                               0
# spm                                0
# location_monitoring_station    27491
# pm2_5                              0
# year                               7
# dtype: int64

# %%
data5 = data4.drop('location_monitoring_station',axis=1)
data5
# Out:
#              sampling_date                        state   location  \
# 0       February - M021990               Andhra Pradesh  Hyderabad
# 1       February - M021990               Andhra Pradesh  Hyderabad
# 2       February - M021990               Andhra Pradesh  Hyderabad
# 3          March - M031990               Andhra Pradesh  Hyderabad
# 4          March - M031990               Andhra Pradesh  Hyderabad
# ...                    ...                          ...        ...
# 435737            24-12-15                  West Bengal   ULUBERIA
# 435738            29-12-15                  West Bengal   ULUBERIA
# 435739                 NaN  andaman-and-nicobar-islands        NaN
# 435740                 NaN                  Lakshadweep        NaN
# 435741                 NaN                      Tripura        NaN
#
#                                       type   so2   no2   rspm    spm  pm2_5  \
# 0       Residential, Rural and other Areas   4.8  17.4  108.0  220.0   40.0
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Outliers in so2

# %%
plt.boxplot(data5['so2'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21a88955820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21a88955dc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21a88955550>],
#  'medians': [<matplotlib.lines.Line2D at 0x21a889643a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21a88964670>],
#  'means': []}

# %%
q1 = np.quantile(data5['so2'],0.25)
q3 = np.quantile(data5['so2'],0.75)

iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

outlier = []
for x in data5['so2']:
    if((x>upper_bound) or (x<lower_bound)):
        outlier.append(x)
print(outlier)
# Out:
# [44.8, 28.7, 35.8, 52.6, 55.8, 33.4, 43.6, 32.9, 36.1, 34.5, 136.1, 67.4, 32.7, 90.0, 44.6, 94.3, 29.1, 79.0, 34.1, 51.6, 31.7, 25.4, 28.3, 31.7, 25.5, 36.8, 44.3, 26.8, 31.0, 40.6, 38.1, 28.1, 27.0, 41.0, 31.8, 38.8, 32.0, 26.2, 28.3, 42.6, 71.4, 37.7, 39.2, 31.4, 32.9, 30.7, 28.8, 26.0, 33.4, 25.9, 29.6, 30.9, 43.1, 27.3, 36.5, 33.6, 28.9, 58.7, 33.0, 37.2, 34.1, 35.3, 73.6, 28.0, 33.9, 35.7, 78.7, 43.2, 55.0, 50.7, 43.7, 32.8, 27.8, 26.1, 35.7, 37.2, 26.0, 48.3, 32.5, 32.9, 35.3, 37.1, 27.7, 38.1, 36.9, 29.1, 28.0, 27.3, 42.3, 43.8, 27.7, 34.0, 37.5, 28.7, 45.4, 28.1, 28.9, 35.0, 26.1, 30.7, 28.6, 27.6, 34.2, 26.4, 26.0, 32.7, 46.8, 91.7, 91.1, 78.6, 45.4, 51.4, 34.8, 91.3, 38.8, 26.8, 28.0, 27.6, 31.6, 29.4, 27.2, 37.6, 37.8, 43.0, 37.0, 83.0, 47.0, 65.0, 32.1, 30.0, 31.4, 35.4, 25.9, 31.0, 31.3, 32.2, 31.4, 25.5, 31.0, 36.2, 32.9, 27.8, 31.4, 32.6, 26.1, 35.6, 48.8, 29.2, 28.8, 61.0, 30.5, 27.0, 28.8, 47.1, 27.1, 73.9, 42.7, 44.5, 26.1, 36.7, 35.9, 29.3, 45.5, 25.1, 182.2, 112.5
# ...

# %%
new_data1 = data5[(data5['so2'] <= upper_bound) & (data5['so2'] >= lower_bound)]

# %%
plt.boxplot(new_data1['so2'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21a88b91550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21a88b91af0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21a88b91280>],
#  'medians': [<matplotlib.lines.Line2D at 0x21a88b9f0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21a88b9f3a0>],
#  'means': []}

# %% [markdown]
# ## Outliers in no2

# %%
plt.boxplot(data5['no2'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21a93a243d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21a93a24970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21a93a24100>],
#  'medians': [<matplotlib.lines.Line2D at 0x21a93a24f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21a93a2f220>],
#  'means': []}

# %%
q1 = np.quantile(data5['no2'],0.25)
q3 = np.quantile(data5['no2'],0.75)

iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

outlier = []
for x in data5['no2']:
    if((x>upper_bound) or (x<lower_bound)):
        outlier.append(x)
print(outlier)
# Out:
# [64.6, 89.6, 66.5, 144.8, 61.0, 162.2, 127.7, 122.4, 61.7, 68.0, 61.8, 172.4, 101.6, 63.0, 95.3, 91.4, 59.4, 85.1, 192.4, 101.7, 111.3, 87.2, 62.3, 66.8, 60.1, 79.1, 62.9, 77.6, 69.4, 144.1, 206.9, 68.9, 61.4, 98.1, 201.6, 64.4, 177.3, 76.9, 265.2, 80.8, 217.8, 75.1, 86.1, 62.6, 113.3, 63.0, 67.7, 123.3, 59.5, 108.6, 63.6, 60.1, 62.2, 66.0, 60.3, 82.4, 60.0, 82.2, 82.5, 69.5, 78.3, 73.6, 65.8, 73.0, 59.8, 65.5, 110.3, 134.1, 79.5, 86.2, 81.3, 80.1, 80.8, 75.8, 84.2, 64.5, 61.1, 69.8, 59.9, 69.9, 59.5, 60.7, 64.6, 63.5, 60.7, 68.7, 82.0, 71.7, 73.2, 59.6, 79.8, 60.1, 60.7, 63.4, 64.8, 59.1, 70.9, 76.2, 60.0, 72.0, 79.6, 68.8, 73.8, 83.8, 75.2, 69.7, 63.7, 72.2, 65.5, 61.7, 78.5, 76.5, 69.7, 65.0, 64.8, 76.2, 97.3, 72.0, 67.0, 76.4, 65.3, 63.7, 77.4, 66.2, 65.9, 61.1, 73.7, 65.3, 69.2, 60.4, 65.3, 63.7, 66.6, 66.6, 62.9, 81.1, 76.9, 79.5, 61.1, 61.4, 61.0, 60.8, 82.6, 79.0, 85.0, 62.7, 105.6, 70.4, 89.7, 101.3, 120.9, 82.6, 99.3, 72.4, 65.3, 97.3, 61.6, 116.0, 81.0, 61.9, 91.1, 62.1, 8
# ...

# %%
new_data2 = data5[(data5['no2'] <= upper_bound) & (data5['no2'] >= lower_bound)]

# %%
plt.boxplot(new_data2['no2'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21a93b210d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21a93b21670>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21a93b11dc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21a93b21c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21a93b21ee0>],
#  'means': []}

# %% [markdown]
# ## Outliers in rspm

# %%
plt.boxplot(data5['rspm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21a9c710940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21a9c710ee0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21a9c710670>],
#  'medians': [<matplotlib.lines.Line2D at 0x21a9c7204c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21a9c720790>],
#  'means': []}

# %%
q1 = np.quantile(data5['rspm'],0.25)
q3 = np.quantile(data5['rspm'],0.75)

iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

outlier = []
for x in data5['rspm']:
    if((x>upper_bound) or (x<lower_bound)):
        outlier.append(x)
print(outlier)
# Out:
# [271.0, 294.0, 321.0, 294.0, 289.0, 285.0, 325.0, 493.0, 323.0, 275.0, 425.0, 274.0, 254.0, 268.0, 253.0, 318.0, 301.0, 252.0, 415.0, 278.0, 267.0, 277.0, 252.0, 286.0, 285.0, 303.0, 538.0, 538.0, 299.0, 372.0, 253.0, 251.0, 307.0, 257.0, 266.0, 258.0, 341.0, 250.0, 322.0, 318.0, 368.0, 252.0, 292.0, 295.0, 322.0, 280.0, 252.0, 312.0, 367.0, 256.0, 355.0, 276.0, 276.0, 275.0, 261.0, 309.0, 330.0, 404.0, 400.0, 637.0, 558.0, 361.0, 363.0, 280.0, 293.0, 250.0, 250.0, 271.0, 290.0, 308.0, 268.0, 253.0, 282.0, 297.0, 254.0, 255.0, 250.0, 267.0, 278.0, 292.0, 264.0, 266.0, 257.0, 298.0, 326.0, 258.0, 388.0, 383.0, 399.0, 414.0, 301.0, 280.0, 463.0, 447.0, 370.0, 462.0, 350.0, 268.0, 264.0, 258.0, 313.0, 286.0, 269.0, 268.0, 263.0, 264.0, 257.0, 502.0, 275.0, 282.0, 769.0, 455.0, 354.0, 307.0, 310.0, 250.0, 257.0, 253.0, 250.0, 257.0, 251.0, 276.0, 266.0, 260.0, 278.0, 299.0, 256.0, 269.0, 274.0, 321.0, 278.0, 288.0, 252.0, 314.0, 280.0, 257.0, 270.0, 317.0, 296.0, 485.0, 252.0, 261.0, 367
# ...

# %%
new_data3 = data5[(data5['rspm'] <= upper_bound) & (data5['rspm'] >= lower_bound)]

# %%
plt.boxplot(new_data3['rspm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21ab459c8e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21ab459ce80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21ab459c610>],
#  'medians': [<matplotlib.lines.Line2D at 0x21ab45ae460>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21ab45ae730>],
#  'means': []}

# %% [markdown]
# ## Outlier is spm

# %%
plt.boxplot(data5['spm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21a9c780310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21a9c7808b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21a9c780040>],
#  'medians': [<matplotlib.lines.Line2D at 0x21a9c780e50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21a9c78c160>],
#  'means': []}

# %%
q1 = np.quantile(data5['spm'],0.25)
q3 = np.quantile(data5['spm'],0.75)

iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

outlier = []
for x in data5['spm']:
    if((x>upper_bound) or (x<lower_bound)):
        outlier.append(x)
print(outlier)
# Out:
# [133.0, 82.0, 111.0, 118.0, 135.0, 80.0, 58.0, 99.0, 270.0, 97.0, 167.0, 145.0, 75.0, 93.0, 61.0, 255.0, 148.0, 77.0, 125.0, 330.0, 93.0, 287.0, 85.0, 283.0, 108.0, 121.0, 84.0, 154.0, 150.0, 67.0, 128.0, 119.0, 71.0, 98.0, 172.0, 56.0, 120.0, 135.0, 83.0, 158.0, 163.0, 103.0, 149.0, 129.0, 353.0, 261.0, 679.0, 320.0, 334.0, 271.0, 118.0, 129.0, 171.0, 555.0, 250.0, 171.0, 122.0, 248.0, 276.0, 134.0, 135.0, 433.0, 253.0, 262.0, 159.0, 267.0, 147.0, 418.0, 175.0, 249.0, 152.0, 173.0, 125.0, 142.0, 344.0, 174.0, 247.0, 95.0, 160.0, 403.0, 145.0, 131.0, 115.0, 112.0, 121.0, 95.0, 167.0, 150.0, 100.0, 152.0, 274.0, 90.0, 128.0, 163.0, 85.0, 141.0, 264.0, 95.0, 166.0, 314.0, 249.0, 75.0, 138.0, 140.0, 158.0, 320.0, 137.0, 347.0, 98.0, 130.0, 144.0, 98.0, 58.0, 91.0, 124.0, 125.0, 94.0, 259.0, 107.0, 132.0, 93.0, 46.0, 44.0, 76.0, 128.0, 60.0, 62.0, 123.0, 31.0, 167.0, 262.0, 97.0, 328.0, 251.0, 247.0, 362.0, 284.0, 82.0, 127.0, 134.0, 115.0, 168.0, 120.0, 120.0, 146.0, 63.0, 151.0, 39.0, 
# ...

# %%
new_data4 = data5[(data5['spm'] <= upper_bound) & (data5['spm'] >= lower_bound)]

# %%
plt.boxplot(new_data4['spm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21ab452ffd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21ab453e5b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21ab452fd00>],
#  'medians': [<matplotlib.lines.Line2D at 0x21ab453eb50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21ab453ee20>],
#  'means': []}

# %% [markdown]
# ## Outliers in pm2_5

# %%
plt.boxplot(data5['pm2_5'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21ab48fdc70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21ab490b250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21ab48fd9a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21ab490b7f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21ab490bac0>],
#  'means': []}

# %%
q1 = np.quantile(data5['pm2_5'],0.25)
q3 = np.quantile(data5['pm2_5'],0.75)

iqr = q3 - q1
upper_bound = q3+(1.5*iqr)
lower_bound = q1-(1.5*iqr)

outlier = []
for x in data5['pm2_5']:
    if((x>upper_bound) or (x<lower_bound)):
        outlier.append(x)
print(outlier)
# Out:
# [35.0, 32.0, 35.0, 24.0, 32.0, 22.0, 27.0, 29.0, 27.0, 34.0, 31.0, 27.0, 23.0, 28.0, 26.0, 29.0, 29.0, 35.0, 33.0, 34.0, 32.0, 28.0, 32.0, 35.0, 28.0, 32.0, 35.0, 37.0, 29.0, 25.0, 29.0, 25.0, 23.0, 33.0, 31.0, 36.0, 34.0, 33.0, 32.0, 35.0, 34.0, 32.0, 30.0, 30.0, 28.0, 23.0, 22.0, 28.0, 27.0, 30.0, 26.0, 29.0, 28.0, 23.0, 25.0, 21.0, 19.0, 22.0, 25.0, 26.0, 23.0, 33.0, 31.0, 29.0, 28.0, 26.0, 27.0, 30.0, 25.0, 28.0, 27.0, 25.0, 29.0, 26.0, 25.0, 28.0, 25.0, 33.0, 31.0, 36.0, 34.0, 33.0, 32.0, 35.0, 34.0, 32.0, 30.0, 78.0, 83.0, 146.0, 62.0, 112.0, 62.0, 63.0, 107.0, 57.0, 44.0, 47.0, 75.0, 47.0, 78.0, 82.0, 78.0, 71.0, 58.0, 77.0, 53.0, 29.0, 89.0, 91.0, 97.0, 61.0, 101.0, 77.0, 77.0, 126.0, 76.0, 55.0, 42.0, 112.0, 100.0, 82.0, 92.0, 85.0, 83.0, 42.0, 62.0, 86.0, 66.0, 52.0, 36.0, 44.0, 32.0, 58.0, 65.0, 87.0, 28.0, 78.0, 110.0, 71.0, 63.0, 51.0, 99.0, 98.0, 76.0, 154.0, 158.0, 111.0, 115.0, 163.0, 56.0, 127.0, 161.0, 122.0, 110.0, 155.0, 163.0, 144.0, 135.0, 121.0, 101.0, 165.0, 1
# ...

# %%
new_data5 = data5[(data5['pm2_5'] <= upper_bound) & (data5['pm2_5'] >= lower_bound)]

# %%
plt.boxplot(new_data5['spm'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21a88a00e20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21a88a10400>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21a88a00b50>],
#  'medians': [<matplotlib.lines.Line2D at 0x21a88a109a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21a88a10c70>],
#  'means': []}

# %% [markdown]
# ### Heart.csv

# %%
data2.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data2['sex']=data2['sex'].replace([0,1],['female','male'])
data2
# Out:
#       age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    male   0       125   212    0        1      168      0      1.0
# 1      53    male   0       140   203    1        0      155      1      3.1
# 2      70    male   0       145   174    0        1      125      1      2.6
# 3      61    male   0       148   203    0        1      161      0      0.0
# 4      62  female   0       138   294    1        1      106      0      1.9
# ...   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    male   1       140   221    0        1      164      1      0.0
# 1021   60    male   0       125   258    0        0      141      1      2.8
# 1022   47    male   0       110   275    0        0      118      1      1.0
# 1023   50  female   0       110   254    0        0      159      0      0.0
# 1024   54    male   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# ...

# %%
data2['cp']=data2['cp'].replace([0,1,2,3],['typical angina','atypical angina','non-anginal pain','asymptomatic'])
data2
# Out:
#       age     sex               cp  trestbps  chol  fbs  restecg  thalach  \
# 0      52    male   typical angina       125   212    0        1      168
# 1      53    male   typical angina       140   203    1        0      155
# 2      70    male   typical angina       145   174    0        1      125
# 3      61    male   typical angina       148   203    0        1      161
# 4      62  female   typical angina       138   294    1        1      106
# ...   ...     ...              ...       ...   ...  ...      ...      ...
# 1020   59    male  atypical angina       140   221    0        1      164
# 1021   60    male   typical angina       125   258    0        0      141
# 1022   47    male   typical angina       110   275    0        0      118
# 1023   50  female   typical angina       110   254    0        0      159
# 1024   54    male   typical angina       120   188    0        1      113
#
#       exang  oldpeak  slope  ca  thal  target
# ...

# %%
data2['exang']=data2['exang'].replace([0,1],['no','yes'])
data2
# Out:
#       age     sex               cp  trestbps  chol  fbs  restecg  thalach  \
# 0      52    male   typical angina       125   212    0        1      168
# 1      53    male   typical angina       140   203    1        0      155
# 2      70    male   typical angina       145   174    0        1      125
# 3      61    male   typical angina       148   203    0        1      161
# 4      62  female   typical angina       138   294    1        1      106
# ...   ...     ...              ...       ...   ...  ...      ...      ...
# 1020   59    male  atypical angina       140   221    0        1      164
# 1021   60    male   typical angina       125   258    0        0      141
# 1022   47    male   typical angina       110   275    0        0      118
# 1023   50  female   typical angina       110   254    0        0      159
# 1024   54    male   typical angina       120   188    0        1      113
#
#      exang  oldpeak  slope  ca  thal  target
# ...

# %%
data2['slope']=data2['slope'].replace([0,1,2],['upsloping','flat','downsloping'])
data2
# Out:
#       age     sex               cp  trestbps  chol  fbs  restecg  thalach  \
# 0      52    male   typical angina       125   212    0        1      168
# 1      53    male   typical angina       140   203    1        0      155
# 2      70    male   typical angina       145   174    0        1      125
# 3      61    male   typical angina       148   203    0        1      161
# 4      62  female   typical angina       138   294    1        1      106
# ...   ...     ...              ...       ...   ...  ...      ...      ...
# 1020   59    male  atypical angina       140   221    0        1      164
# 1021   60    male   typical angina       125   258    0        0      141
# 1022   47    male   typical angina       110   275    0        0      118
# 1023   50  female   typical angina       110   254    0        0      159
# 1024   54    male   typical angina       120   188    0        1      113
#
#      exang  oldpeak        slope  ca  thal  target
# ...

# %%
data2['thal']=data2['thal'].replace([0,1,2,3],['nan','normal','fixed defect','reversable defect'])
data2
# Out:
#       age     sex               cp  trestbps  chol  fbs  restecg  thalach  \
# 0      52    male   typical angina       125   212    0        1      168
# 1      53    male   typical angina       140   203    1        0      155
# 2      70    male   typical angina       145   174    0        1      125
# 3      61    male   typical angina       148   203    0        1      161
# 4      62  female   typical angina       138   294    1        1      106
# ...   ...     ...              ...       ...   ...  ...      ...      ...
# 1020   59    male  atypical angina       140   221    0        1      164
# 1021   60    male   typical angina       125   258    0        0      141
# 1022   47    male   typical angina       110   275    0        0      118
# 1023   50  female   typical angina       110   254    0        0      159
# 1024   54    male   typical angina       120   188    0        1      113
#
#      exang  oldpeak        slope  ca               thal  target
# ...

# %%
data2['fbs']=data2['fbs'].replace([0,1],['false','true'])
data2
# Out:
#       age     sex               cp  trestbps  chol    fbs  restecg  thalach  \
# 0      52    male   typical angina       125   212  false        1      168
# 1      53    male   typical angina       140   203   true        0      155
# 2      70    male   typical angina       145   174  false        1      125
# 3      61    male   typical angina       148   203  false        1      161
# 4      62  female   typical angina       138   294   true        1      106
# ...   ...     ...              ...       ...   ...    ...      ...      ...
# 1020   59    male  atypical angina       140   221  false        1      164
# 1021   60    male   typical angina       125   258  false        0      141
# 1022   47    male   typical angina       110   275  false        0      118
# 1023   50  female   typical angina       110   254  false        0      159
# 1024   54    male   typical angina       120   188  false        1      113
#
# ...

# %%
data2['restecg']=data2['restecg'].replace([0,1,2],['normal','having ST-T wave abnormality','showing probable or definite left ventricular hypertrophy by Estes’ criteria'])
data2
# Out:
#       age     sex               cp  trestbps  chol    fbs  \
# 0      52    male   typical angina       125   212  false
# 1      53    male   typical angina       140   203   true
# 2      70    male   typical angina       145   174  false
# 3      61    male   typical angina       148   203  false
# 4      62  female   typical angina       138   294   true
# ...   ...     ...              ...       ...   ...    ...
# 1020   59    male  atypical angina       140   221  false
# 1021   60    male   typical angina       125   258  false
# 1022   47    male   typical angina       110   275  false
# 1023   50  female   typical angina       110   254  false
# 1024   54    male   typical angina       120   188  false
#
#                            restecg  thalach exang  oldpeak        slope  ca  \
# 0     having ST-T wave abnormality      168    no      1.0  downsloping   2
# 1                           normal      155   yes      3.1    upsloping   0
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   object
#  2   cp        1025 non-null   object
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   object
#  6   restecg   1025 non-null   object
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   object
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   object
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   object
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(6), object(7)
# memory usage: 112.2+ KB

# %%
data2.ca.unique()
# Out:
# array([2, 0, 1, 3, 4], dtype=int64)

# %%
data2['ca'].value_counts()
# Out:
# 0    578
# 1    226
# 2    134
# 3     69
# 4     18
# Name: ca, dtype: int64

# %%
data2[data2['ca']==4]
# Out:
#      age   sex                cp  trestbps  chol    fbs  \
# 52    38  male  non-anginal pain       138   175  false
# 83    38  male  non-anginal pain       138   175  false
# 128   52  male  non-anginal pain       138   223  false
# 208   38  male  non-anginal pain       138   175  false
# 242   38  male  non-anginal pain       138   175  false
# 290   52  male  non-anginal pain       138   223  false
# 340   38  male  non-anginal pain       138   175  false
# 348   43  male    typical angina       132   247   true
# 417   52  male  non-anginal pain       138   223  false
# 428   43  male    typical angina       132   247   true
# 465   38  male  non-anginal pain       138   175  false
# 521   58  male   atypical angina       125   220  false
# 597   38  male  non-anginal pain       138   175  false
# 743   58  male   atypical angina       125   220  false
# 749   58  male   atypical angina       125   220  false
# 831   58  male   atypical angina       125   220  false
# ...

# %%
data2['ca']=data2['ca'].replace(4,np.nan)

# %%
data2.ca.unique()
# Out:
# array([ 2.,  0.,  1.,  3., nan])

# %%
import matplotlib.pyplot as plt

# %%
x = data2.iloc[:,13]
y = data2.iloc[:,4]

plt.bar(x,y, color ='maroon',width = 0.4)
plt.xlabel('target')
plt.ylabel('chol')

plt.show()

# %%
data2.boxplot(column=['chol'])
# Out:
# <AxesSubplot:>

# %%
data2.boxplot(column=['chol','thalach'])
# Out:
# <AxesSubplot:>

# %%
plt.boxplot(data2['chol'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21a8bf14580>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21a8bf14b20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21a8bf142b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21a8bf0c100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21a8bf0c3d0>],
#  'means': []}

# %%
chol_q1 = np.quantile(data2['chol'],0.25)
chol_q3 = np.quantile(data2['chol'],0.75)

chol_iqr = chol_q3 - chol_q1
upper_bound = chol_q3+(1.5*chol_iqr)
lower_bound = chol_q1-(1.5*chol_iqr)

outlier = []
for x in data2['chol']:
    if((x>upper_bound) or (x<lower_bound)):
        outlier.append(x)
print(outlier)
# Out:
# [417, 564, 409, 564, 394, 407, 564, 407, 394, 394, 409, 417, 407, 407, 417, 409]

# %%
new_data = data2[(data2['chol'] <= upper_bound) & (data2['chol'] >= lower_bound)]

# %%
plt.boxplot(new_data['chol'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21a888f7a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x21a88906070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x21a888f77c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x21a88906610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21a889068e0>],
#  'means': []}
